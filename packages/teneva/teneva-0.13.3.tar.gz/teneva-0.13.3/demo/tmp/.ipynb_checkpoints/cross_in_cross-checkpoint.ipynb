# %%
import matplotlib.pyplot as plt
import numpy as np
import teneva
from time import perf_counter as tpc
np.random.seed(42)

# %%
e_qtt = 1.E-3

def cross_matrix_spec(f, I1, I2):
    n1 = I1.shape[0]
    n2 = I2.shape[0]
    
    q1 = int(np.log2(n1))
    q2 = int(np.log2(n2))
    q = q1 + q2
    
    if 2**q1 != n1 or 2**q2 != n2:
        raise NotImplementedError('Mode size and rank should be power of 2')
    
    def func(I):
        I_base = []
        for i in I:
            i1 = teneva.ind_qtt_to_tt(i[:q1], q1)[0]
            i2 = teneva.ind_qtt_to_tt(i[q1:], q2)[0]
            i1_base = I1[i1]
            i2_base = I2[i2]
            I_base.append(np.hstack((i1_base, i2_base)))
        I_base = np.array(I_base, dtype=int)
        return f(I_base)
    
    info = {}
    Y = teneva.tensor_rand([2]*q, 1)
    Y = teneva.cross(func, Y, e=e_qtt, cache={}, info=info, log=False)
    Y = teneva.full(Y).reshape(n1, n2, order='F')
    
    return Y, info['m']

# %%
def _ones(k, m=1):
    return np.ones((k, m), dtype=int)

# %%
def _reshape(A, n, order='F'):
    return np.reshape(A, n, order=order)

# %%
def _func_new(f, Ig, Ir, Ic, info, cache=None):
    if cache is not None:
        raise NotImplementedError('Cache is not supported in fast cross')
    
    n = Ig.shape[0]
    r1 = Ir.shape[0] if Ir is not None else 1
    r2 = Ic.shape[0] if Ic is not None else 1

    if info['m_max'] is not None and info['m'] + r1*n*r2 > info['m_max']:
        return None

    if Ic is not None:
        I2 = Ic
    else:
        I = np.kron(np.kron(_ones(r2), Ig), _ones(r1))
        Ir_ = np.kron(_ones(n * r2), Ir)
        I = np.hstack((Ir_, I))
        
        y = f(I)
        info['m'] += len(y)
        
        return _reshape(y, (r1, n, r2))

    I1 = np.kron(Ig, _ones(r1))
    if Ir is not None:
        I1 = np.hstack((np.kron(_ones(n), Ir), I1))
    
    y, m = cross_matrix_spec(f, I1, I2)
    info['m'] += m
    
    return _reshape(y, (r1, n, r2))

# %%
def func_cross(func, Y0, m, with_info=False, is_new=False):
    func.clear()
    
    func.prep(Y0)
    func.cross(m, dr_max=0, cache=None, func=_func_new if is_new else None)
    
    if is_new:
        func.method += '-FAST'
    
    func.check()
    if with_info:
        func.info(f'm = {func.m:7.1e}')
    
    return {'t': func.t, 'm': func.m, 'e': func.e_tst_ind}

# %%
d = 10               # Dimension
n = 1024             # Grid size
r = 4                # TT-rank
with_info = True     # If true, then logs will be printed

print(f'One sweep is : {d * n * r * r:-7.1e}')
# Out:
# One sweep is: 1.6e+05

# %%
m_list = [5.E+4, 6.E+4, 7.E+4, 8.E+4, 9.E+4, 1.E+5, 2.E+5, 3.E+5, 4.E+5, 5.E+5]
result = {}

for m in m_list:
    for func in teneva.func_demo_all(d):
        func.set_grid(n, kind='uni')
        func.build_tst_ind(1.E+3)
        
        Y0 = teneva.tensor_rand(func.n, r)
        
        data_old = func_cross(func, Y0, m, with_info)
        data_new = func_cross(func, Y0, m, with_info, is_new=True)
        
        if not func.name in result:
            result[func.name] = {'old': [], 'new': []}
        
        result[func.name]['old'].append(data_old)
        result[func.name]['new'].append(data_new)
        
        if with_info:
            print()
# Out:
# Ackley          [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   1.709 | m = 3.7e+04
# Ackley          [CRO-FAST     ] > error: 3.5e-03 | rank:  4.0 | time:   3.385 | m = 3.6e+04
#
# Alpine          [CRO          ] > error: 1.0e+00 | rank:  3.5 | time:   0.678 | m = 3.7e+04
# Alpine          [CRO-FAST     ] > error: 2.6e-04 | rank:  2.1 | time:   3.435 | m = 3.6e+04
#
# Dixon           [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.710 | m = 3.7e+04
# Dixon           [CRO-FAST     ] > error: 1.2e-14 | rank:  3.4 | time:   3.978 | m = 4.1e+04
#
# Exponential     [CRO          ] > error: 1.0e+00 | rank:  3.3 | time:   0.690 | m = 3.7e+04
# Exponential     [CRO-FAST     ] > error: 1.8e-11 | rank:  2.1 | time:   3.432 | m = 3.4e+04
#
# Grienwank       [CRO          ] > error: 1.0e+00 | rank:  3.8 | time:   0.678 | m = 3.7e+04
# Grienwank       [CRO-FAST     ] > error: 4.6e-13 | rank:  3.3 | time:   3.524 | m = 3.4e+04
#
# Michalewicz     [CRO          ] > error: 1.0e+00 | rank:  3.5 | time:   0.690 | m = 3.7e+04
# Michalewicz     [CRO-FAST     ] > error: 9.1e-03 | rank:  2.5 | time:   2.975 | m = 3.4e+04
#
# Qing            [CRO          ] > error: 1.0e+00 | rank:  3.5 | time:   0.679 | m = 3.7e+04
# Qing            [CRO-FAST     ] > error: 4.0e-15 | rank:  2.2 | time:   3.469 | m = 3.4e+04
#
# Rastrigin       [CRO          ] > error: 1.0e+00 | rank:  3.5 | time:   0.677 | m = 3.7e+04
# Rastrigin       [CRO-FAST     ] > error: 2.9e-15 | rank:  2.1 | time:   3.531 | m = 3.4e+04
#
# Rosenbrock      [CRO          ] > error: 1.0e+00 | rank:  3.8 | time:   0.664 | m = 3.7e+04
# Rosenbrock      [CRO-FAST     ] > error: 1.3e-14 | rank:  3.2 | time:   3.696 | m = 3.4e+04
#
# Schaffer        [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.677 | m = 3.7e+04
# Schaffer        [CRO-FAST     ] > error: 5.9e-02 | rank:  4.0 | time:   4.330 | m = 4.2e+04
#
# Schwefel        [CRO          ] > error: 1.0e+00 | rank:  3.5 | time:   0.668 | m = 3.7e+04
# Schwefel        [CRO-FAST     ] > error: 9.9e-06 | rank:  2.4 | time:   3.205 | m = 3.5e+04
#
# Ackley          [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.764 | m = 5.3e+04
# Ackley          [CRO-FAST     ] > error: 2.1e-03 | rank:  4.0 | time:   4.134 | m = 4.5e+04
#
# Alpine          [CRO          ] > error: 1.0e+00 | rank:  3.3 | time:   0.752 | m = 5.3e+04
# Alpine          [CRO-FAST     ] > error: 7.6e-03 | rank:  3.2 | time:   4.087 | m = 4.4e+04
#
# Dixon           [CRO          ] > error: 1.0e+00 | rank:  3.7 | time:   0.752 | m = 5.3e+04
# Dixon           [CRO-FAST     ] > error: 1.3e-12 | rank:  3.5 | time:   4.225 | m = 4.4e+04
#
# Exponential     [CRO          ] > error: 1.0e+00 | rank:  3.2 | time:   0.749 | m = 5.3e+04
# Exponential     [CRO-FAST     ] > error: 1.9e-11 | rank:  1.6 | time:   4.742 | m = 4.4e+04
#
# Grienwank       [CRO          ] > error: 1.0e+00 | rank:  3.7 | time:   0.761 | m = 5.3e+04
# Grienwank       [CRO-FAST     ] > error: 8.5e-13 | rank:  3.4 | time:   3.938 | m = 4.5e+04
#
# Michalewicz     [CRO          ] > error: 1.0e+00 | rank:  3.3 | time:   0.767 | m = 5.3e+04
# Michalewicz     [CRO-FAST     ] > error: 2.1e-04 | rank:  2.3 | time:   3.916 | m = 4.5e+04
#
# Qing            [CRO          ] > error: 1.0e+00 | rank:  3.3 | time:   0.759 | m = 5.3e+04
# Qing            [CRO-FAST     ] > error: 5.4e-15 | rank:  2.3 | time:   5.232 | m = 4.4e+04
#
# Rastrigin       [CRO          ] > error: 1.0e+00 | rank:  3.2 | time:   0.762 | m = 5.3e+04
# Rastrigin       [CRO-FAST     ] > error: 8.6e-15 | rank:  2.1 | time:   4.346 | m = 5.3e+04
#
# Rosenbrock      [CRO          ] > error: 1.0e+00 | rank:  3.7 | time:   0.764 | m = 5.3e+04
# Rosenbrock      [CRO-FAST     ] > error: 1.1e-14 | rank:  3.6 | time:   4.324 | m = 4.6e+04
#
# Schaffer        [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.758 | m = 5.3e+04
# Schaffer        [CRO-FAST     ] > error: 5.4e-02 | rank:  4.0 | time:   4.886 | m = 4.7e+04
#
# Schwefel        [CRO          ] > error: 1.0e+00 | rank:  3.4 | time:   0.759 | m = 5.3e+04
# Schwefel        [CRO-FAST     ] > error: 7.0e-06 | rank:  2.5 | time:   4.210 | m = 4.6e+04
#
# Ackley          [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.857 | m = 7.0e+04
# Ackley          [CRO-FAST     ] > error: 3.9e-03 | rank:  4.0 | time:   5.239 | m = 5.5e+04
#
# Alpine          [CRO          ] > error: 1.0e+00 | rank:  3.1 | time:   0.864 | m = 7.0e+04
# Alpine          [CRO-FAST     ] > error: 1.6e-03 | rank:  3.7 | time:   5.319 | m = 5.4e+04
#
# Dixon           [CRO          ] > error: 1.0e+00 | rank:  3.9 | time:   0.846 | m = 7.0e+04
# Dixon           [CRO-FAST     ] > error: 1.8e-14 | rank:  3.2 | time:   5.758 | m = 5.5e+04
#
# Exponential     [CRO          ] > error: 1.0e+00 | rank:  3.1 | time:   0.838 | m = 7.0e+04
# Exponential     [CRO-FAST     ] > error: 1.3e-11 | rank:  1.6 | time:   5.193 | m = 5.4e+04
#
# Grienwank       [CRO          ] > error: 1.0e+00 | rank:  3.5 | time:   0.837 | m = 7.0e+04
# Grienwank       [CRO-FAST     ] > error: 2.9e-14 | rank:  3.0 | time:   5.320 | m = 5.5e+04
#
# Michalewicz     [CRO          ] > error: 1.0e+00 | rank:  3.3 | time:   0.870 | m = 7.0e+04
# Michalewicz     [CRO-FAST     ] > error: 5.0e-04 | rank:  2.9 | time:   4.733 | m = 5.4e+04
#
# Qing            [CRO          ] > error: 1.0e+00 | rank:  3.1 | time:   0.842 | m = 7.0e+04
# Qing            [CRO-FAST     ] > error: 6.5e-07 | rank:  2.1 | time:   5.664 | m = 5.4e+04
#
# Rastrigin       [CRO          ] > error: 1.0e+00 | rank:  3.2 | time:   0.842 | m = 7.0e+04
# Rastrigin       [CRO-FAST     ] > error: 5.9e-15 | rank:  2.4 | time:   4.757 | m = 5.4e+04
#
# Rosenbrock      [CRO          ] > error: 1.0e+00 | rank:  3.8 | time:   0.835 | m = 7.0e+04
# Rosenbrock      [CRO-FAST     ] > error: 2.4e-14 | rank:  3.0 | time:   5.256 | m = 5.5e+04
#
# Schaffer        [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.852 | m = 7.0e+04
# Schaffer        [CRO-FAST     ] > error: 5.7e-02 | rank:  4.0 | time:   5.872 | m = 5.6e+04
#
# Schwefel        [CRO          ] > error: 1.0e+00 | rank:  3.0 | time:   0.858 | m = 7.0e+04
# Schwefel        [CRO-FAST     ] > error: 3.1e-06 | rank:  2.1 | time:   4.955 | m = 5.5e+04
#
# Ackley          [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.847 | m = 7.0e+04
# Ackley          [CRO-FAST     ] > error: 2.4e-03 | rank:  4.0 | time:   6.698 | m = 6.7e+04
#
# Alpine          [CRO          ] > error: 1.0e+00 | rank:  3.0 | time:   0.852 | m = 7.0e+04
# Alpine          [CRO-FAST     ] > error: 1.1e-03 | rank:  3.4 | time:   6.091 | m = 6.4e+04
#
# Dixon           [CRO          ] > error: 1.0e+00 | rank:  3.5 | time:   0.846 | m = 7.0e+04
# Dixon           [CRO-FAST     ] > error: 1.1e-12 | rank:  3.4 | time:   6.246 | m = 6.6e+04
#
# Exponential     [CRO          ] > error: 1.0e+00 | rank:  3.0 | time:   0.850 | m = 7.0e+04
# Exponential     [CRO-FAST     ] > error: 1.1e-11 | rank:  2.0 | time:   6.663 | m = 6.4e+04
#
# Grienwank       [CRO          ] > error: 1.0e+00 | rank:  3.8 | time:   0.892 | m = 7.0e+04
# Grienwank       [CRO-FAST     ] > error: 8.4e-14 | rank:  3.1 | time:   6.385 | m = 7.2e+04
#
# Michalewicz     [CRO          ] > error: 1.0e+00 | rank:  3.0 | time:   0.880 | m = 7.0e+04
# Michalewicz     [CRO-FAST     ] > error: 9.7e-04 | rank:  3.0 | time:   6.317 | m = 6.8e+04
#
# Qing            [CRO          ] > error: 1.0e+00 | rank:  3.1 | time:   0.840 | m = 7.0e+04
# Qing            [CRO-FAST     ] > error: 7.9e-15 | rank:  2.2 | time:   7.247 | m = 6.4e+04
#
# Rastrigin       [CRO          ] > error: 1.0e+00 | rank:  3.1 | time:   0.852 | m = 7.0e+04
# Rastrigin       [CRO-FAST     ] > error: 4.6e-15 | rank:  2.0 | time:   5.779 | m = 6.6e+04
#
# Rosenbrock      [CRO          ] > error: 1.0e+00 | rank:  3.9 | time:   0.850 | m = 7.0e+04
# Rosenbrock      [CRO-FAST     ] > error: 1.7e-14 | rank:  3.0 | time:   6.685 | m = 6.4e+04
#
# Schaffer        [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.840 | m = 7.0e+04
# Schaffer        [CRO-FAST     ] > error: 6.4e-02 | rank:  4.0 | time:   6.966 | m = 6.6e+04
#
# Schwefel        [CRO          ] > error: 1.0e+00 | rank:  3.1 | time:   0.842 | m = 7.0e+04
# Schwefel        [CRO-FAST     ] > error: 6.6e-06 | rank:  2.5 | time:   5.635 | m = 6.8e+04
#
# Ackley          [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.938 | m = 8.6e+04
# Ackley          [CRO-FAST     ] > error: 3.1e-03 | rank:  4.0 | time:   7.261 | m = 7.5e+04
#
# Alpine          [CRO          ] > error: 1.0e+00 | rank:  3.0 | time:   0.943 | m = 8.6e+04
# Alpine          [CRO-FAST     ] > error: 1.2e-03 | rank:  2.3 | time:   7.090 | m = 8.1e+04
#
# Dixon           [CRO          ] > error: 1.0e+00 | rank:  3.4 | time:   0.957 | m = 8.6e+04
# Dixon           [CRO-FAST     ] > error: 2.3e-14 | rank:  3.2 | time:   6.830 | m = 7.4e+04
#
# Exponential     [CRO          ] > error: 1.0e+00 | rank:  2.9 | time:   0.930 | m = 8.6e+04
# Exponential     [CRO-FAST     ] > error: 1.5e-11 | rank:  2.4 | time:   6.881 | m = 7.4e+04
#
# Grienwank       [CRO          ] > error: 1.0e+00 | rank:  3.6 | time:   0.924 | m = 8.6e+04
# Grienwank       [CRO-FAST     ] > error: 3.4e-13 | rank:  3.0 | time:   6.515 | m = 7.4e+04
#
# Michalewicz     [CRO          ] > error: 1.0e+00 | rank:  2.8 | time:   0.959 | m = 8.6e+04
# Michalewicz     [CRO-FAST     ] > error: 1.6e-03 | rank:  2.5 | time:   7.303 | m = 8.5e+04
#
# Qing            [CRO          ] > error: 1.0e+00 | rank:  2.8 | time:   0.927 | m = 8.6e+04
# Qing            [CRO-FAST     ] > error: 5.1e-15 | rank:  2.2 | time:   7.704 | m = 7.4e+04
#
# Rastrigin       [CRO          ] > error: 1.0e+00 | rank:  2.9 | time:   0.932 | m = 8.6e+04
# Rastrigin       [CRO-FAST     ] > error: 8.6e-15 | rank:  2.3 | time:   6.877 | m = 7.4e+04
#
# Rosenbrock      [CRO          ] > error: 1.0e+00 | rank:  3.6 | time:   0.946 | m = 8.6e+04
# Rosenbrock      [CRO-FAST     ] > error: 8.1e-15 | rank:  3.4 | time:   7.372 | m = 7.4e+04
#
# Schaffer        [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.956 | m = 8.6e+04
# Schaffer        [CRO-FAST     ] > error: 6.5e-02 | rank:  4.0 | time:   8.470 | m = 7.4e+04
#
# Schwefel        [CRO          ] > error: 1.0e+00 | rank:  3.0 | time:   0.967 | m = 8.6e+04
# Schwefel        [CRO-FAST     ] > error: 2.4e-06 | rank:  2.2 | time:   6.198 | m = 7.4e+04
#
# Ackley          [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.948 | m = 8.6e+04
# Ackley          [CRO-FAST     ] > error: 3.1e-03 | rank:  4.0 | time:   8.315 | m = 8.9e+04
#
# Alpine          [CRO          ] > error: 1.0e+00 | rank:  3.2 | time:   0.944 | m = 8.6e+04
# Alpine          [CRO-FAST     ] > error: 9.7e-04 | rank:  2.4 | time:   7.820 | m = 8.8e+04
#
# Dixon           [CRO          ] > error: 1.0e+00 | rank:  3.6 | time:   0.967 | m = 8.6e+04
# Dixon           [CRO-FAST     ] > error: 9.5e-13 | rank:  3.2 | time:   8.846 | m = 9.2e+04
#
# Exponential     [CRO          ] > error: 1.0e+00 | rank:  2.9 | time:   0.980 | m = 8.6e+04
# Exponential     [CRO-FAST     ] > error: 1.1e-11 | rank:  1.7 | time:   8.562 | m = 8.4e+04
#
# Grienwank       [CRO          ] > error: 1.0e+00 | rank:  3.6 | time:   0.981 | m = 8.6e+04
# Grienwank       [CRO-FAST     ] > error: 3.8e-14 | rank:  3.0 | time:   8.517 | m = 8.5e+04
#
# Michalewicz     [CRO          ] > error: 1.0e+00 | rank:  2.9 | time:   1.009 | m = 8.6e+04
# Michalewicz     [CRO-FAST     ] > error: 5.9e-04 | rank:  2.2 | time:   7.572 | m = 8.5e+04
#
# Qing            [CRO          ] > error: 1.0e+00 | rank:  2.8 | time:   0.948 | m = 8.6e+04
# Qing            [CRO-FAST     ] > error: 7.7e-15 | rank:  2.3 | time:  10.013 | m = 8.4e+04
#
# Rastrigin       [CRO          ] > error: 1.0e+00 | rank:  2.8 | time:   0.952 | m = 8.6e+04
# Rastrigin       [CRO-FAST     ] > error: 9.2e-15 | rank:  2.1 | time:   7.578 | m = 8.6e+04
#
# Rosenbrock      [CRO          ] > error: 1.0e+00 | rank:  3.4 | time:   0.943 | m = 8.6e+04
# Rosenbrock      [CRO-FAST     ] > error: 2.3e-14 | rank:  3.0 | time:   8.206 | m = 8.4e+04
#
# Schaffer        [CRO          ] > error: 1.0e+00 | rank:  4.0 | time:   0.969 | m = 8.6e+04
# Schaffer        [CRO-FAST     ] > error: 6.8e-02 | rank:  4.0 | time:   9.734 | m = 8.6e+04
#
# Schwefel        [CRO          ] > error: 1.0e+00 | rank:  2.8 | time:   0.956 | m = 8.6e+04
# Schwefel        [CRO-FAST     ] > error: 4.2e-06 | rank:  2.1 | time:   7.312 | m = 8.5e+04
#
# Ackley          [CRO          ] > error: 4.2e-03 | rank:  4.0 | time:   1.512 | m = 1.9e+05
# Ackley          [CRO-FAST     ] > error: 6.9e-03 | rank:  4.0 | time:  17.849 | m = 1.8e+05
#
# Alpine          [CRO          ] > error: 3.5e-15 | rank:  2.1 | time:   1.501 | m = 1.9e+05
# Alpine          [CRO-FAST     ] > error: 7.2e-04 | rank:  2.0 | time:  16.156 | m = 1.8e+05
#
# Dixon           [CRO          ] > error: 1.7e-14 | rank:  3.1 | time:   1.599 | m = 1.9e+05
# Dixon           [CRO-FAST     ] > error: 3.8e-14 | rank:  3.3 | time:  17.759 | m = 1.9e+05
#
# Exponential     [CRO          ] > error: 9.5e-16 | rank:  1.7 | time:   1.440 | m = 1.9e+05
# Exponential     [CRO-FAST     ] > error: 2.1e-11 | rank:  1.6 | time:  18.092 | m = 1.8e+05
#
# Grienwank       [CRO          ] > error: 6.8e-13 | rank:  3.0 | time:   1.527 | m = 1.9e+05
# Grienwank       [CRO-FAST     ] > error: 4.4e-13 | rank:  3.2 | time:  17.176 | m = 1.9e+05
#
# Michalewicz     [CRO          ] > error: 8.0e-15 | rank:  2.4 | time:   1.538 | m = 1.9e+05
# Michalewicz     [CRO-FAST     ] > error: 6.6e-04 | rank:  2.4 | time:  16.403 | m = 1.8e+05
#
# Qing            [CRO          ] > error: 3.8e-15 | rank:  2.1 | time:   1.438 | m = 1.9e+05
# Qing            [CRO-FAST     ] > error: 4.0e-15 | rank:  2.1 | time:  21.100 | m = 1.8e+05
#
# Rastrigin       [CRO          ] > error: 7.9e-15 | rank:  2.0 | time:   1.464 | m = 1.9e+05
# Rastrigin       [CRO-FAST     ] > error: 3.9e-15 | rank:  2.6 | time:  15.977 | m = 1.8e+05
#
# Rosenbrock      [CRO          ] > error: 6.6e-15 | rank:  3.2 | time:   1.517 | m = 1.9e+05
# Rosenbrock      [CRO-FAST     ] > error: 1.4e-14 | rank:  3.4 | time:  17.442 | m = 1.8e+05
#
# Schaffer        [CRO          ] > error: 5.4e-02 | rank:  4.0 | time:   1.574 | m = 1.9e+05
# Schaffer        [CRO-FAST     ] > error: 6.8e-02 | rank:  4.0 | time:  21.306 | m = 2.0e+05
#
# Schwefel        [CRO          ] > error: 3.2e-15 | rank:  2.5 | time:   1.474 | m = 1.9e+05
# Schwefel        [CRO-FAST     ] > error: 4.1e-06 | rank:  2.4 | time:  15.150 | m = 1.8e+05
#
# Ackley          [CRO          ] > error: 3.4e-03 | rank:  4.0 | time:   2.306 | m = 3.0e+05
# Ackley          [CRO-FAST     ] > error: 4.7e-03 | rank:  4.0 | time:  28.100 | m = 2.9e+05
#
# Alpine          [CRO          ] > error: 7.1e-15 | rank:  2.1 | time:   2.281 | m = 3.0e+05
# Alpine          [CRO-FAST     ] > error: 3.9e-03 | rank:  2.1 | time:  25.895 | m = 2.8e+05
#
# Dixon           [CRO          ] > error: 3.2e-14 | rank:  3.1 | time:   2.331 | m = 3.0e+05
# Dixon           [CRO-FAST     ] > error: 2.2e-13 | rank:  3.3 | time:  27.330 | m = 2.9e+05
#
# Exponential     [CRO          ] > error: 9.9e-16 | rank:  1.1 | time:   2.188 | m = 3.0e+05
# Exponential     [CRO-FAST     ] > error: 1.8e-11 | rank:  1.8 | time:  28.542 | m = 2.8e+05
#
# Grienwank       [CRO          ] > error: 1.7e-15 | rank:  3.2 | time:   2.249 | m = 3.0e+05
# Grienwank       [CRO-FAST     ] > error: 2.2e-12 | rank:  3.2 | time:  25.994 | m = 2.8e+05
#
# Michalewicz     [CRO          ] > error: 3.0e-15 | rank:  2.1 | time:   2.305 | m = 3.0e+05
# Michalewicz     [CRO-FAST     ] > error: 2.6e-04 | rank:  2.5 | time:  25.932 | m = 2.9e+05
#
# Qing            [CRO          ] > error: 1.2e-15 | rank:  2.1 | time:   2.200 | m = 3.0e+05
# Qing            [CRO-FAST     ] > error: 1.7e-14 | rank:  2.1 | time:  32.811 | m = 2.8e+05
#
# Rastrigin       [CRO          ] > error: 6.7e-15 | rank:  2.0 | time:   2.101 | m = 3.0e+05
# Rastrigin       [CRO-FAST     ] > error: 1.2e-14 | rank:  2.4 | time:  24.155 | m = 2.8e+05
#
# Rosenbrock      [CRO          ] > error: 9.7e-15 | rank:  3.0 | time:   2.283 | m = 3.0e+05
# Rosenbrock      [CRO-FAST     ] > error: 2.3e-14 | rank:  3.1 | time:  27.086 | m = 2.8e+05
#
# Schaffer        [CRO          ] > error: 9.1e-02 | rank:  4.0 | time:   2.374 | m = 3.0e+05
# Schaffer        [CRO-FAST     ] > error: 6.8e-02 | rank:  4.0 | time:  30.936 | m = 2.9e+05
#
# Schwefel        [CRO          ] > error: 6.8e-15 | rank:  2.0 | time:   2.302 | m = 3.0e+05
# Schwefel        [CRO-FAST     ] > error: 3.4e-06 | rank:  2.7 | time:  23.308 | m = 2.8e+05
#
# Ackley          [CRO          ] > error: 4.2e-03 | rank:  4.0 | time:   2.776 | m = 4.0e+05
# Ackley          [CRO-FAST     ] > error: 9.0e-03 | rank:  4.0 | time:  38.189 | m = 3.8e+05
#
# Alpine          [CRO          ] > error: 3.3e-15 | rank:  2.4 | time:   2.901 | m = 4.0e+05
# Alpine          [CRO-FAST     ] > error: 1.1e-03 | rank:  2.9 | time:  36.687 | m = 3.8e+05
#
# Dixon           [CRO          ] > error: 7.1e-13 | rank:  3.5 | time:   2.834 | m = 4.0e+05
# Dixon           [CRO-FAST     ] > error: 8.4e-15 | rank:  3.4 | time:  39.585 | m = 3.9e+05
#
# Exponential     [CRO          ] > error: 1.4e-15 | rank:  1.9 | time:   2.882 | m = 4.0e+05
# Exponential     [CRO-FAST     ] > error: 2.1e-11 | rank:  1.8 | time:  40.621 | m = 3.8e+05
#
# Grienwank       [CRO          ] > error: 1.7e-12 | rank:  3.3 | time:   2.839 | m = 4.0e+05
# Grienwank       [CRO-FAST     ] > error: 4.8e-15 | rank:  3.1 | time:  37.594 | m = 3.9e+05
#
# Michalewicz     [CRO          ] > error: 5.8e-15 | rank:  2.2 | time:   3.001 | m = 4.0e+05
# Michalewicz     [CRO-FAST     ] > error: 3.4e-03 | rank:  3.2 | time:  38.502 | m = 3.8e+05
#
# Qing            [CRO          ] > error: 2.8e-15 | rank:  2.0 | time:   2.788 | m = 4.0e+05
# Qing            [CRO-FAST     ] > error: 6.7e-15 | rank:  2.3 | time:  43.935 | m = 3.8e+05
#
# Rastrigin       [CRO          ] > error: 9.9e-15 | rank:  2.1 | time:   2.637 | m = 4.0e+05
# Rastrigin       [CRO-FAST     ] > error: 4.9e-15 | rank:  2.1 | time:  33.541 | m = 3.9e+05
#
# Rosenbrock      [CRO          ] > error: 7.9e-15 | rank:  3.5 | time:   2.787 | m = 4.0e+05
# Rosenbrock      [CRO-FAST     ] > error: 2.5e-14 | rank:  3.0 | time:  40.070 | m = 3.8e+05
#
# Schaffer        [CRO          ] > error: 7.0e-02 | rank:  4.0 | time:   2.959 | m = 4.0e+05
# Schaffer        [CRO-FAST     ] > error: 7.8e-02 | rank:  4.0 | time:  45.470 | m = 3.9e+05
#
# Schwefel        [CRO          ] > error: 5.0e-15 | rank:  2.4 | time:   2.873 | m = 4.0e+05
# Schwefel        [CRO-FAST     ] > error: 4.1e-06 | rank:  2.2 | time:  36.018 | m = 3.8e+05
#
# Ackley          [CRO          ] > error: 5.8e-03 | rank:  4.0 | time:   3.327 | m = 4.9e+05
# Ackley          [CRO-FAST     ] > error: 7.8e-03 | rank:  4.0 | time:  54.025 | m = 4.9e+05
#
# Alpine          [CRO          ] > error: 2.2e-15 | rank:  2.2 | time:   3.339 | m = 4.9e+05
# Alpine          [CRO-FAST     ] > error: 2.2e-03 | rank:  2.0 | time:  51.649 | m = 4.9e+05
#
# Dixon           [CRO          ] > error: 3.4e-14 | rank:  3.1 | time:   3.621 | m = 4.9e+05

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, 12))

plt.figure(figsize=(12, 12), dpi=80)

for i, (name, data) in enumerate(result.items()):
    m_old = [item['m'] for item in data['old']]
    e_old = [item['e'] for item in data['old']]
    
    m_new = [item['m'] for item in data['new']]
    e_new = [item['e'] for item in data['new']]
    
    plt.plot(m_new, e_new, '-' , color=colors[i], marker='s', label=name)
    plt.plot(m_old, e_old, '--', color=colors[i], marker='o')

plt.title(f'Result | d = {d:-4d} | n = {n:-4d} | r = {r:-4d} |')
plt.xlabel('Number of requests')
plt.ylabel('Relative error')
plt.semilogx()
plt.semilogy()
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ---
