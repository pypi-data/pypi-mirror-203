# %%
# %matplotlib inline

# %%
# Third party imports
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import pandas as pd

# Local imports
from libcomcat.dataframes import get_history_data_frame, split_history_frame, PRODUCTS
from libcomcat.search import get_event_by_id

# %% [markdown]
# # ComCat Event History

# %% [markdown]
# Use this function to download a summary DataFrame of all of the products associated with a given ComCat ID. The M7.1 event from the Ridgecrest Earthquake Sequence in July 2019 is used in this example.

# %% [markdown]
# *Note: If modifying the analysis, run the cell below*

# %%
history_event = get_event_by_id('ci38457511', includesuperseded=True)
dataframe, event = get_history_data_frame(history_event)

# %% [markdown]
# *If presenting, run the cell below instead.*

# %%
excelfile = 'data/ci38457511_history.xlsx'
if 'dataframe' not in vars():
    history_event = get_event_by_id('ci38457511', includesuperseded=True)
    dataframe = pd.read_excel(excelfile)
else:
    dataframe.to_excel(excelfile)

# %% [markdown]
# Use head() to inspect the columns and first five rows. The products are sorted by "update time", which is supposed to be the time the PDL client sends the product, but some producers override this manually.

# %%
print(len(dataframe))
dataframe.head()
# Out:
# 1564
#    Unnamed: 0.1  Unnamed: 0             Update Time     Product  \
# 0             0        1516 2019-07-06 03:22:22.060  phase-data
# 1             1        1502 2019-07-06 03:22:22.060      origin
# 2             2           0 2019-07-06 03:23:03.442        dyfi
# 3             3        1517 2019-07-06 03:24:53.240  phase-data
# 4             4        1503 2019-07-06 03:24:53.240      origin
#
#   Authoritative Event ID        Code  Associated Product Source  \
# 0             ci38457511  ci38457511        True             ci
# 1             ci38457511  ci38457511        True             ci
# 2             ci38457511  ci38457511        True             us
# 3             ci38457511  ci38457511        True             ci
# 4             ci38457511  ci38457511        True             ci
#
#    Product Version  Elapsed (min)  \
# 0                1            2.5
# 1                1            2.5
# 2                1            3.2
# 3                2            5.0
# 4                2            5.0
#
#                                                  URL  Comment  \
# 0  https://earthquake.usgs.gov/archive/product/ph...      NaN
# 1  https://earthquake.usgs.gov/archive/product/or...      NaN
# 2  https://earthquake.usgs.gov/archive/product/dy...      NaN
# 3  https://earthquake.usgs.gov/archive/product/ph...      NaN
# 4  https://earthquake.usgs.gov/archive/product/or...      NaN
#
#                                          Description
# 0  Magnitude# 7.1|Time# 2019-07-06 03:19:52.63000...
# 1  Magnitude# 7.1|Time# 2019-07-06 03:19:52.63000...
# 2                      Max MMI# 3.8|NumResponses# 15
# 3  Magnitude# 6.9|Time# 2019-07-06 03:19:52.63000...
# 4  Magnitude# 6.9|Time# 2019-07-06 03:19:52.63000...

# %% [markdown]
# The dataframe downloaded has all kinds of products in it. It can be used with the split_history_frame() function to extract just the origins and look at those.

# %%
origin_frame = split_history_frame(dataframe,product='origin')
origin_frame
# Out:
#     Unnamed: 0.1  Unnamed: 0             Update Time Product  \
# 0              1        1502 2019-07-06 03:22:22.060  origin
# 1              4        1503 2019-07-06 03:24:53.240  origin
# 2              7        1496 2019-07-06 03:25:49.786  origin
# 3              9        1504 2019-07-06 03:27:00.170  origin
# 4             13        1495 2019-07-06 03:33:09.715  origin
# 5             16        1497 2019-07-06 03:37:21.040  origin
# 6             21        1505 2019-07-06 03:42:15.950  origin
# 7             28        1506 2019-07-06 04:01:42.060  origin
# 8             41        1507 2019-07-06 04:41:22.640  origin
# 9             74        1498 2019-07-06 06:43:30.040  origin
# 10           308        1508 2019-07-07 04:16:11.140  origin
# 11           771        1509 2019-07-08 22:51:49.940  origin
# 12          1309        1510 2019-07-16 16:17:25.185  origin
# 13          1484        1499 2019-08-07 21:19:34.040  origin
# 14          1498        1500 2019-08-14 22:24:59.040  origin
# 15          1547        1501 2019-09-26 14:30:23.040  origin
#
#    Authoritative Event ID        Code  Associated Product Source  \
# 0              ci38457511  ci38457511        True             ci
# 1              ci38457511  ci38457511        True             ci
# 2              ci38457511  at00pu7alg        True             at
# 3              ci38457511  ci38457511        True             ci
# 4              ci38457511  pt19187000        True             pt
# 5              ci38457511  us70004bn0        True             us
# 6              ci38457511  ci38457511        True             ci
# 7              ci38457511  ci38457511        True             ci
# 8              ci38457511  ci38457511        True             ci
# 9              ci38457511  us70004bn0        True             us
# 10             ci38457511  ci38457511        True             ci
# 11             ci38457511  ci38457511        True             ci
# 12             ci38457511  ci38457511        True             ci
# 13             ci38457511  us70004bn0        True             us
# 14             ci38457511  us70004bn0        True             us
# 15             ci38457511  us70004bn0        True             us
#
#     Product Version  Elapsed (min)  ... Magnitude                    Time  \
# 0                 1            2.5  ...       7.1 2019-07-06 03:19:52.630
# 1                 2            5.0  ...       6.9 2019-07-06 03:19:52.630
# 2                 1            5.9  ...       7.1 2019-07-06 03:20:04.000
# 3                 3            7.1  ...       6.9 2019-07-06 03:19:52.630
# 4                 1           13.3  ...       7.1 2019-07-06 03:19:53.000
# 5                 1           17.5  ...       7.1 2019-07-06 03:19:52.630
# 6                 4           22.4  ...       7.1 2019-07-06 03:19:52.630
# 7                 5           41.8  ...       7.1 2019-07-06 03:19:52.630
# 8                 6           81.5  ...       7.1 2019-07-06 03:19:52.630
# 9                 2          203.6  ...       7.1 2019-07-06 03:19:52.630
# 10                7         1496.3  ...       7.1 2019-07-06 03:19:52.820
# 11                8         4051.9  ...       7.1 2019-07-06 03:19:53.040
# 12                9        15177.5  ...       7.1 2019-07-06 03:19:53.040
# 13                3        47159.7  ...       7.1 2019-07-06 03:19:53.040
# 14                4        57305.1  ...       7.1 2019-07-06 03:19:53.040
# 15                5       118750.5  ...       7.1 2019-07-06 03:19:53.040
#
#     Time Offset (sec)           Location  Distance from Auth. Origin (km)  \
# 0                -0.4  (35.766,-117.605)                              0.6
# 1                -0.4  (35.766,-117.605)                              0.6
# 2                11.0  (35.488,-117.923)                             42.8
# 3                -0.4  (35.766,-117.605)                              0.6
# 4                -0.0  (35.500,-117.900)                             40.4
# 5                -0.4  (35.767,-117.605)                              0.6
# 6                -0.4  (35.766,-117.605)                              0.6
# 7                -0.4  (35.766,-117.605)                              0.6
# 8                -0.4  (35.766,-117.605)                              0.6
# 9                -0.4  (35.767,-117.605)                              0.6
# 10               -0.2  (35.766,-117.605)                              0.6
# 11                0.0  (35.770,-117.599)                              0.0
# 12                0.0  (35.770,-117.599)                              0.0
# 13                0.0  (35.770,-117.599)                              0.0
# 14                0.0  (35.770,-117.599)                              0.0
# 15                0.0  (35.770,-117.599)                              0.0
#
#    Azimuth  Depth Magnitude Type  Location Method Preferred Weight
# 0       SW   -0.9             me          unknown            156.0
# 1       SW   -0.9             mw          unknown            156.0
# 2       SW  100.0             Mi                l              6.0
# 3       SW   -0.9             mw          unknown            156.0
# 4       SW  100.0             Mi                u              6.0
# 5       SW   -0.9            mww          unknown              6.0
# 6       SW   -0.9             mh          unknown            156.0
# 7       SW   -0.9             mh          unknown            156.0
# 8       SW   17.0             mh          unknown            156.0
# 9       SW   17.0            mww          unknown              6.0
# 10      SW    8.0             mh          unknown            156.0
# 11       N    8.0             mw          unknown            156.0
# 12       N    8.0             mw          unknown            156.0
# 13       E    8.0            mww          unknown              6.0
# 14       E    8.0            mww          unknown              6.0
# 15       E    8.0            mww          unknown              6.0
#
# [16 rows x 22 columns]

# %% [markdown]
# Make a plot showing all of the depths, colored by contributing network.

# %%
fig = plt.figure(figsize=(12,8))
colors = ['r','b','g','k','m']
nets = origin_frame['Product Source'].unique().tolist()
labels = {}
for idx, row in origin_frame.iterrows():
    netidx = nets.index(row['Product Source'])
    color = colors[netidx]
    line = plt.plot(row['Elapsed (min)'],row['Depth'], mfc=color,mec='k',marker='.', ms=24)
    if color not in labels:
        labels[color] = nets[netidx]

patches = []
for color, network in labels.items():
    tpatch = mpatches.Circle(xy=(0,0),color=color, label=network, ec='k')
    patches.append(tpatch)
plt.legend(handles=patches);
plt.title('Evolution of Network Depths');
plt.xlabel('Elapsed Time (min)');
plt.ylabel('Depth (km)');
plt.axhline(y=history_event.depth,color='r');

# %% [markdown]
# Let's similarly split out DYFI products.

# %%
dyfi_frame = split_history_frame(dataframe,product='dyfi')
print(len(dyfi_frame))
dyfi_frame.head()
# Out:
# 1434
#    Unnamed: 0.1  Unnamed: 0             Update Time Product  \
# 0             2           0 2019-07-06 03:23:03.442    dyfi
# 1             8           1 2019-07-06 03:26:31.983    dyfi
# 2            12           2 2019-07-06 03:33:07.443    dyfi
# 3            18           3 2019-07-06 03:39:33.071    dyfi
# 4            22           4 2019-07-06 03:43:08.909    dyfi
#
#   Authoritative Event ID        Code  Associated Product Source  \
# 0             ci38457511  ci38457511        True             us
# 1             ci38457511  ci38457511        True             us
# 2             ci38457511  ci38457511        True             us
# 3             ci38457511  ci38457511        True             us
# 4             ci38457511  ci38457511        True             us
#
#    Product Version  Elapsed (min)  \
# 0                1            3.2
# 1                2            6.6
# 2                3           13.2
# 3                4           19.7
# 4                5           23.3
#
#                                                  URL  Comment  Max MMI  \
# 0  https://earthquake.usgs.gov/archive/product/dy...      NaN      3.8
# 1  https://earthquake.usgs.gov/archive/product/dy...      NaN      9.1
# 2  https://earthquake.usgs.gov/archive/product/dy...      NaN      9.1
# 3  https://earthquake.usgs.gov/archive/product/dy...      NaN      9.1
# 4  https://earthquake.usgs.gov/archive/product/dy...      NaN      9.1
#
#    NumResponses
# 0          15.0
# 1          35.0
# 2          68.0
# 3         121.0
# 4         131.0

# %% [markdown]
# DYFI product updates arrive frequently, so a figure showing the number of responses with time may be useful.

# %%
fig = plt.figure(figsize=(12,8));
plt.plot(dyfi_frame['Elapsed (min)']/(60*24), dyfi_frame['NumResponses'], 'b');
plt.xlabel('Elapsed Time (days)', fontsize=14);
plt.ylabel('Number of Responses', fontsize=14);
plt.title('DYFI Responses', fontsize=16);
# how long did it take to get to 95% of our maximum number of responses?
max_resp_95 = dyfi_frame['NumResponses'].max()*0.95
elapsed = dyfi_frame[dyfi_frame['NumResponses'] >= max_resp_95].iloc[0]['Elapsed (min)']
elapsed_x = elapsed/(60*24)
elapsed_hrs = elapsed/60
plt.axvline(x=elapsed_x,color='r');
etext = '95%% of responses reached within %.1f hours' % elapsed_hrs
plt.text(elapsed_x, dyfi_frame['NumResponses'].mean(),etext, fontsize=14);

# %% [markdown]
# Retrieve ShakeMap data

# %%
sm_frame = split_history_frame(dataframe,product='shakemap')
print(len(sm_frame))
sm_frame.head()
# Out:
# 40
#    Unnamed: 0.1  Unnamed: 0             Update Time   Product  \
# 0             6        1532 2019-07-06 03:25:21.738  shakemap
# 1            25        1524 2019-07-06 03:51:49.683  shakemap
# 2            27        1533 2019-07-06 04:00:46.444  shakemap
# 3            34        1525 2019-07-06 04:12:56.067  shakemap
# 4            36        1547 2019-07-06 04:17:37.814  shakemap
#
#   Authoritative Event ID        Code  Associated Product Source  \
# 0             ci38457511  ci38457511        True             us
# 1             ci38457511  ci38457511        True            cgs
# 2             ci38457511  ci38457511        True             us
# 3             ci38457511  ci38457511        True            cgs
# 4             ci38457511  ci38457511        True             ci
#
#    Product Version  Elapsed (min)  \
# 0                1            5.5
# 1                3           31.9
# 2                2           40.9
# 3                4           53.1
# 4                2           57.7
#
#                                                  URL  Comment  MaxMMI  \
# 0  https://earthquake.usgs.gov/archive/product/sh...      NaN     8.6
# 1  https://earthquake.usgs.gov/archive/product/sh...      NaN     9.2
# 2  https://earthquake.usgs.gov/archive/product/sh...      NaN     8.1
# 3  https://earthquake.usgs.gov/archive/product/sh...      NaN     9.2
# 4  https://earthquake.usgs.gov/archive/product/sh...      NaN     9.4
#
#    Instrumented  DYFI Fault  \
# 0           0.0   0.0   NaT
# 1          61.0   0.0   NaT
# 2         816.0   0.0   NaT
# 3          83.0   0.0   NaT
# 4         795.0   0.0   NaT
#
#                                                 GMPE  Mag  Depth
# 0  AbrahamsonEtAl2014,BooreEtAl2014CaliforniaBasi...  7.1   -0.9
# 1                                               BA08  7.1   -0.9
# 2  AbrahamsonEtAl2014,BooreEtAl2014CaliforniaBasi...  7.1   -0.9
# 3                                               BA08  7.1   -0.9
# 4                                               BA08  7.1   -0.9

# %% [markdown]
# Select the Southern California ShakeMaps

# %%
ci_frame = sm_frame[sm_frame['Product Source'] == 'ci']
ci_frame.head()
# Out:
#     Unnamed: 0.1  Unnamed: 0             Update Time   Product  \
# 4             36        1547 2019-07-06 04:17:37.814  shakemap
# 5             43        1548 2019-07-06 04:44:59.500  shakemap
# 6             47        1549 2019-07-06 05:26:47.524  shakemap
# 15           158        1550 2019-07-06 15:29:29.876  shakemap
# 16           298        1551 2019-07-07 03:30:36.286  shakemap
#
#    Authoritative Event ID        Code  Associated Product Source  \
# 4              ci38457511  ci38457511        True             ci
# 5              ci38457511  ci38457511        True             ci
# 6              ci38457511  ci38457511        True             ci
# 15             ci38457511  ci38457511        True             ci
# 16             ci38457511  ci38457511        True             ci
#
#     Product Version  Elapsed (min)  \
# 4                 2           57.7
# 5                 3           85.1
# 6                 4          126.9
# 15                5          729.6
# 16                6         1450.7
#
#                                                   URL  Comment  MaxMMI  \
# 4   https://earthquake.usgs.gov/archive/product/sh...      NaN     9.4
# 5   https://earthquake.usgs.gov/archive/product/sh...      NaN     9.4
# 6   https://earthquake.usgs.gov/archive/product/sh...      NaN     9.4
# 15  https://earthquake.usgs.gov/archive/product/sh...      NaN     9.4
# 16  https://earthquake.usgs.gov/archive/product/sh...      NaN     9.3
#
#     Instrumented  DYFI Fault  GMPE  Mag  Depth
# 4          795.0   0.0   NaT  BA08  7.1   -0.9
# 5          826.0   0.0   NaT  BA08  7.1   17.0
# 6          826.0   0.0   NaT  BA08  7.1   17.0
# 15         856.0   0.0   NaT  BA08  7.1   17.0
# 16         867.0   0.0   NaT  BA08  7.1    2.3

# %% [markdown]
# Plot the number of instrumented stations over time

# %%
fig = plt.figure(figsize=(12,8));
plt.plot(ci_frame['Elapsed (min)']/(60*24), ci_frame['Instrumented'], 'b');
plt.xlabel('Elapsed Time (days)', fontsize=14);
plt.ylabel('Number of Instrumented Stations', fontsize=14);
plt.title('CI ShakeMap Stations Used', fontsize=16);
